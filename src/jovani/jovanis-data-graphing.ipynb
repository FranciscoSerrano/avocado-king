# %%
# %config IPCompleter.greedy=True
# %matplotlib inline

# %%
# Import dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# File to Load (Remember to change the path if needed.)
avocado_data_to_load = os.path.join("./data/interim", "avocado.pkl")

# Load to data frame from a pickle file.
vis_guacate_df = pd.read_pickle(avocado_data_to_load)
vis_guacate_df
# Out:
#             year          type  AveragePrice  Total Volume        4046  \
# Date
# 2015-01-04  2015       organic          1.75      27365.89     9307.34
# 2015-01-04  2015       organic          1.49      17723.17     1189.35
# 2015-01-04  2015       organic          1.68       2896.72      161.68
# 2015-01-04  2015  conventional          1.52      54956.80     3013.04
# 2015-01-04  2015       organic          1.64       1505.12        1.27
# ...          ...           ...           ...           ...         ...
# 2018-03-25  2018  conventional          1.36     908202.13   142681.06
# 2018-03-25  2018  conventional          0.70    9010588.32  3999735.71
# 2018-03-25  2018       organic          1.42     163496.70    29253.30
# 2018-03-25  2018       organic          1.70     190257.38    29644.09
# 2018-03-25  2018  conventional          1.34    1774776.77    63905.98
#
#                  4225       4770              region
# Date
# ...

# %%
# Testing out some methods to display matplotlib visuals
avo_type = vis_guacate_df.groupby("type")["Total Volume"].agg("sum")
print(avo_type["conventional"])
print(avo_type["organic"])
total = avo_type["conventional"] + avo_type["organic"]
print(avo_type["conventional"]/total)
print(avo_type["organic"]/total)
# Out:
# 15087220911.30996
# 436181682.09000105
# 0.9719016704317486
# 0.028098329568251434

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise of 'conventional' and 'organic':
# https://matplotlib.org/3.1.1/gallery/pie_and_polar_charts/pie_features.html
labels = "conventional", "organic"
sizes = [(avo_type["conventional"]/total), (avo_type["organic"]/total)]
explode = (0, 0.1)  # only "explode" the 2nd slice (i.e. 'Hogs')
fig, ax = plt.subplots()
ax.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax.axis("equal")
# Out:
# (-1.1052939439224068,
#  1.108731140770466,
#  -1.1127044074359183,
#  1.2049589771665552)

# %%
region_list = vis_guacate_df["region"].unique().tolist()
print(region_list)
# Out:
# ['Southeast', 'Chicago', 'HarrisburgScranton', 'Pittsburgh', 'Boise', 'WestTexNewMexico', 'LosAngeles', 'LasVegas', 'Atlanta', 'DallasFtWorth', 'MiamiFtLauderdale', 'Plains', 'StLouis', 'Syracuse', 'Midsouth', 'Sacramento', 'Boston', 'Charlotte', 'Spokane', 'Albany', 'Houston', 'SouthCarolina', 'SanFrancisco', 'TotalUS', 'RaleighGreensboro', 'BuffaloRochester', 'NorthernNewEngland', 'GrandRapids', 'Denver', 'SanDiego', 'BaltimoreWashington', 'Roanoke', 'RichmondNorfolk', 'Northeast', 'SouthCentral', 'GreatLakes', 'Louisville', 'Seattle', 'CincinnatiDayton', 'NewYork', 'NewOrleansMobile', 'Indianapolis', 'Jacksonville', 'Columbus', 'Detroit', 'Philadelphia', 'PhoenixTucson', 'Nashville', 'Portland', 'HartfordSpringfield', 'Tampa', 'Orlando', 'West', 'California']
